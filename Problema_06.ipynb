# %% [markdown]
# Este programa arroja el impuesto que se debe pagar de acuerdo a los ingresos mensuales del personal

# %%
def Impuesto(Sueldo):
  if S < 10000.0:
    print("USTED DEBE PAGAR EL 5% DE SU SUELDO")
    I = S*0.05
    P = S-I
    print("SU SUELDO FINAL SERÍA: ", P)
    return[I, True]
  elif (S >= 10000.0 and S < 15000.0):
    print("USTED DEBE PAGAR EL 10% DE SU SUELDO")
    I = S*0.1
    P = S-I
    print("SU SUELDO FINAL SERÍA: ", P)
    return[I, True]
  elif (S >= 15000.0 and S < 20000.0):
    print("USTED DEBE PAGAR EL 15% DE SU SUELDO")
    I = S*0.15
    P = S-I
    print("SU SUELDO FINAL SERÍA: ", P)
    return[I, True]
  else:
    print("USTED DEBE PAGAR EL 20% DE SU SUELDO")
    I = S*0.2
    P = S-I
    print("SU SUELDO FINAL SERÍA: ", P)
    return[I, True]

S = float(input("INGRESE SU SUELDO MENSUAL: "))
while S < 0:
  S = float(input("INGRESE UN SUELDO REAL: "))

Impuesto(S)

# %% [markdown]
# Braulio Gabriel López Parada 2SV1
