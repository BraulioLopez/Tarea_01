# %% [markdown]
# Este programa realiza el factorial de cualquier número entero

# %%
def Factor(F):
  F = 1
  if (N == 0 or N == 1):
    F = 1
  else:
    for x in range (1, N+1):
      F = F*x
  print("EL FACTORIAL DE", N, "ES: ", F)

N = int(input("INGRESAR UN NÚMERO ENTERO: "))

Factor(N)

# %% [markdown]
# Braulio Gabriel López Parada 2SV1
