# %% [markdown]
# Este programa dibuja un triangulo rectángulo tan grande como el usuario lo indique

# %%
T = int(input("INGRESA UN NÚMERO ENTERO: "))
contador = 0
while (contador < T):
  contador = contador + 1
  print(contador*"*")

# %% [markdown]
# Braulio Gabriel López Parada 2SV1
