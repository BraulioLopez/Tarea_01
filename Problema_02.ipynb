# %% [markdown]
# Este programa imprime el texto que se introduzca tantas veces lo indique el usuario

# %%
T = str(input("TEXTO A IMPRIMIR: "))
N = int(input("VECES QUE SE IMPRIMIRÁ EL TEXTO: "))
C = 0
while C < N:
  C = C + 1
  print (T)

# %% [markdown]
# Braulio Gabriel López Parada
# 2SV1
