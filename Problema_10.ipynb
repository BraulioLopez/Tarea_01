# %% [markdown]
# Este programa calcula el área de un círculo y el volumen de un cilíndro

# %%
def Circulo(C):
  PI = 3.1416
  A = PI*(r**2)
  print("EL ÁREA DEL CIRCULO ES: ", A)
def Cilindro(V):
  PI = 3.1416
  A = PI*(r**2)
  if (h == 0 or h == 0.0):
    return[]
  V = A*h
  print("EL VOLUMEN DEL CILÍNDRO ES: ", V)


r = float(input("INGRESE VALOR DEL RADIO: "))
print ("RADIO = ", r)

Circulo(r)

h = float(input("INGRESE VALOR DE LA ALTURA: "))
print ("ALTURA = ", h)

Cilindro(h)

# %% [markdown]
# Braulio Gabriel López Parada 2SV1
