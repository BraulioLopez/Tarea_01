# %%
def Edad(E):
  if E < 4:
    P = 0.0
  elif (E >= 4 and E <= 16):
    P = 50.0
  else:
    P = 100.0

  if (X == "a" or X == "A"):
    B = P*0.9
  elif (X == "b" or X == "B"):
    B = P*0.7
  elif (X == "c" or X == "C"):
    B = P*0.5
  if (X == "d" or X == "D"):
    B = P
  print("PRECIO DE BOLETO: ", B)
    

E = int(input("INGRESE SU EDAD: "))
while E < 0:
  E = int(input("INGRESE SU EDAD: "))
print("A = ESTUDIANTE    B = DOCENTE    C = INAPAM    D = NINGUNO")
X = str(input("SELECCIONE EL TIPO DE DESCUENTO: "))

Edad (E)

# %% [markdown]
# Braulio Gabriel López Parada 2SV1
