# %% [markdown]
# Este programa calcula el peso de los pedidos realizados a una juguetería, que determina si está dentro de los parámetros de o se pasa

# %%
def Peso(Payaso, Mesa):
  Payaso = 0.15
  PW = P*Payaso
  print("DE ", P, " PAYASOS, SON:", PW, "KG.")
  Mesa = 0.17
  JW = J*Mesa
  print("DE ", J, " JUEGOS DE MESA, SON:", JW, "KG.")
  TW = PW+JW
  print("EL PESO TOTAL DEL PEDIDO ES:", TW, "KG.")
  if TW > 10:
    Exceso= TW-10
    return[Exceso, False]
  else:
    return['EL PEDIDO PUEDE REALIZARSE', True]
    
P = int(input("NÚMERO DE PAYASOS: "))
while P < 0:
  P = int(input("VALOR INVÁLIDO, INTRODUCIR UNO QUE SEA MAYOR O IGUAL A CERO: "))
J = int(input("NÚMERO DE JUEGOS DE MESA: "))
while J < 0:
  J = int(input("VALOR INVÁLIDO, INTRODUCIR UNO QUE SEA MAYOR O IGUAL A CERO: "))
Peso(P, J)

# %% [markdown]
# Braulio Gabriel López Parada 2SV1
